# %% [markdown]
# IMPORTANT: This notebook is meant to be run on Google Collab, will not work for you on local unless you have powerful Nvidia GPU
#
# https://colab.research.google.com/drive/185RaaIFspi9x2EYM42CUbrWjAYha1ynZ?usp=sharing

# %%
# !pip install -U transformers pandas
# Out:
# Requirement already satisfied: transformers in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (4.53.0)
# Collecting transformers
#   Downloading transformers-4.53.2-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: pandas in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (2.3.0)
# Collecting pandas
#   Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (0.33.1)
# Requirement already satisfied: numpy>=1.17 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from requests->transformers) (2025.6.15)
# Downloading transformers-4.53.2-py3-none-any.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ----------------------- ---------------- 6.3/10.8 MB 36.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 33.9 MB/s eta 0:00:00
# Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 11.0/11.0 MB 53.9 MB/s eta 0:00:00
# Installing collected packages: pandas, transformers
#
#   Attempting uninstall: pandas
#
#     Found existing installation: pandas 2.3.0
#
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#     Uninstalling pandas-2.3.0:
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#       Successfully uninstalled pandas-2.3.0
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#   Attempting uninstall: transformers
#    ---------------------------------------- 0/2 [pandas]
#     Found existing installation: transformers 4.53.0
#    ---------------------------------------- 0/2 [pandas]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#     Uninstalling transformers-4.53.0:
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#       Successfully uninstalled transformers-4.53.0
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    ---------------------------------------- 2/2 [transformers]
#
# Successfully installed pandas-2.3.1 transformers-4.53.2

# %%
from huggingface_hub import login
login(new_session=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\repos\Cohort2-w1\Week1\week1_env\Lib\site-packages\huggingface_hub\_login.py:340, in notebook_login(new_session, write_permission)
#     339 try:
# --> 340     import ipywidgets.widgets as widgets  # type: ignore
#     341     from IPython.display import display  # type: ignore
#
# ModuleNotFoundError: No module named 'ipywidgets'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 from huggingface_hub import login
# ----> 2 login(new_session=False)
#
# File c:\repos\Cohort2-w1\Week1\week1_env\Lib\site-packages\huggingface_hub\utils\_deprecation.py:101, in _deprecate_arguments.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      99         message += "\n\n" + custom_message
#     100     warnings.warn(message, FutureWarning)
# --> 101 return f(*args, **kwargs)
#
# File c:\repos\Cohort2-w1\Week1\week1_env\Lib\site-packages\huggingface_hub\utils\_deprecation.py:31, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      29 extra_args = len(args) - len(all_args)
#      30 if extra_args <= 0:
# ---> 31     return f(*args, **kwargs)
#      32 # extra_args > 0
#      33 args_msg = [
#      34     f"{name}='{arg}'" if isinstance(arg, str) else f"{name}={arg}"
#      35     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      36 ]
#
# File c:\repos\Cohort2-w1\Week1\week1_env\Lib\site-packages\huggingface_hub\_login.py:128, in login(token, add_to_git_credential, new_session, write_permission)
#     126     _login(token, add_to_git_credential=add_to_git_credential)
#     127 elif is_notebook():
# --> 128     notebook_login(new_session=new_session)
#     129 else:
#     130     interpreter_login(new_session=new_session)
#
# File c:\repos\Cohort2-w1\Week1\week1_env\Lib\site-packages\huggingface_hub\utils\_deprecation.py:101, in _deprecate_arguments.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      99         message += "\n\n" + custom_message
#     100     warnings.warn(message, FutureWarning)
# --> 101 return f(*args, **kwargs)
#
# File c:\repos\Cohort2-w1\Week1\week1_env\Lib\site-packages\huggingface_hub\utils\_deprecation.py:31, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      29 extra_args = len(args) - len(all_args)
#      30 if extra_args <= 0:
# ---> 31     return f(*args, **kwargs)
#      32 # extra_args > 0
#      33 args_msg = [
#      34     f"{name}='{arg}'" if isinstance(arg, str) else f"{name}={arg}"
#      35     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      36 ]
#
# File c:\repos\Cohort2-w1\Week1\week1_env\Lib\site-packages\huggingface_hub\_login.py:343, in notebook_login(new_session, write_permission)
#     341     from IPython.display import display  # type: ignore
#     342 except ImportError:
# --> 343     raise ImportError(
#     344         "The `notebook_login` function can only be used in a notebook (Jupyter or"
#     345         " Colab) and you need the `ipywidgets` module: `pip install ipywidgets`."
#     346     )
#     347 if not new_session and get_token() is not None:
#     348     logger.info("User is already logged in.")
#
# ImportError: The `notebook_login` function can only be used in a notebook (Jupyter or Colab) and you need the `ipywidgets` module: `pip install ipywidgets`.

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="mistralai/Mistral-7B-Instruct-v0.3")
messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe(messages)

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.3")
model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.3")

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="auto",
    api_key=os.environ["HF_TOKEN"],
)

completion = client.chat.completions.create(
    model="mistralai/Mistral-7B-Instruct-v0.3",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
)

print(completion.choices[0].message)

# %%
# prompt: Can you do another chat completions call but this time — show log probabilities of top 10 tokens for each token inferred. And then the final message

import math, pandas as pd


completion = client.chat.completions.create(
    model="mistralai/Mistral-7B-Instruct-v0.3",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    logprobs=True,
    top_logprobs=5,
)
# print(completion.choices[0].message)
# completion.choices[0].logprobs

logprobs = completion.choices[0].logprobs     # shortcut
records = []
for idx, (tok, lp, top) in enumerate(zip(
        logprobs.tokens,
        logprobs.token_logprobs,
        logprobs.top_logprobs)):

    chosen = f"{tok} ({math.exp(lp):.3f})"
    alts = sorted(top.items(), key=lambda kv: kv[1], reverse=True)[:5]
    alts_fmt = [f"{t} ({math.exp(lp_):.3f})" for t, lp_ in alts]
    alts_fmt += [''] * (5 - len(alts_fmt))          # pad to 5

    records.append([idx, chosen, *alts_fmt])

df = pd.DataFrame(records,
                  columns=["Idx", "Chosen (p)", "Alt-1", "Alt-2",
                           "Alt-3", "Alt-4", "Alt-5"])

print(df.to_string(index=False))

# %%
# prompt: Do same question "What is capital of france" with chat completion — allow controlling other factors like output tokens, temperature

completion = client.chat.completions.create(
    model="mistralai/Mistral-7B-Instruct-v0.3",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    max_tokens=10,  # Set the maximum number of output tokens
    temperature=2 # Set the temperature for creativity (0.0 to 1.0)
)

completion.choices[0].message.content
