# %% [markdown]
# IMPORTANT: This notebook is meant to be run on Google Collab, will not work for you on local unless you have powerful Nvidia GPU
#
# https://colab.research.google.com/drive/185RaaIFspi9x2EYM42CUbrWjAYha1ynZ?usp=sharing

# %%
# !pip install -U transformers pandas
# Out:
# Requirement already satisfied: transformers in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (4.53.2)
# Requirement already satisfied: pandas in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (2.3.1)
# Requirement already satisfied: filelock in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (0.33.1)
# Requirement already satisfied: numpy>=1.17 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\repos\cohort2-w1\week1\week1_env\lib\site-packages (from requests->transformers) (2025.6.15)

# %%
# %pip install ipywidgets

# %%
import os
from dotenv import load_dotenv
load_dotenv()

aa=os.environ["HF_TOKEN"]
print(aa)

# %%
from huggingface_hub import login
login(new_session=False)

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="mistralai/Mistral-7B-Instruct-v0.3")
messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe(messages)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.3")
model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.3")

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="auto",
    api_key=os.environ["HF_TOKEN"],
)

completion = client.chat.completions.create(
    model="mistralai/Mistral-7B-Instruct-v0.3",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
)

print(completion.choices[0].message)

# %%
# prompt: Can you do another chat completions call but this time — show log probabilities of top 10 tokens for each token inferred. And then the final message

import math, pandas as pd


completion = client.chat.completions.create(
    model="mistralai/Mistral-7B-Instruct-v0.3",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    logprobs=True,
    top_logprobs=5,
)
# print(completion.choices[0].message)
# completion.choices[0].logprobs

logprobs = completion.choices[0].logprobs     # shortcut
records = []
for idx, (tok, lp, top) in enumerate(zip(
        logprobs.tokens,
        logprobs.token_logprobs,
        logprobs.top_logprobs)):

    chosen = f"{tok} ({math.exp(lp):.3f})"
    alts = sorted(top.items(), key=lambda kv: kv[1], reverse=True)[:5]
    alts_fmt = [f"{t} ({math.exp(lp_):.3f})" for t, lp_ in alts]
    alts_fmt += [''] * (5 - len(alts_fmt))          # pad to 5

    records.append([idx, chosen, *alts_fmt])

df = pd.DataFrame(records,
                  columns=["Idx", "Chosen (p)", "Alt-1", "Alt-2",
                           "Alt-3", "Alt-4", "Alt-5"])

print(df.to_string(index=False))

# %%
# prompt: Do same question "What is capital of france" with chat completion — allow controlling other factors like output tokens, temperature

completion = client.chat.completions.create(
    model="mistralai/Mistral-7B-Instruct-v0.3",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    max_tokens=10,  # Set the maximum number of output tokens
    temperature=2 # Set the temperature for creativity (0.0 to 1.0)
)

completion.choices[0].message.content
